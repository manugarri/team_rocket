# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from poliastro.examples import molniya
from poliastro.plotting import plot
plot(molniya)

# %%
import numpy as np
from astropy import units as u
from poliastro.bodies import Earth, Sun
from poliastro.twobody import State

# Data for Mars at J2000 from JPL HORIZONS
a = 2.7681117 * u.AU
ecc = 0.0757544 * u.one
inc = 10.59166 * u.deg
raan = 80.3218 * u.deg
argp = 72.73324 * u.deg
nu = 181.38133 * u.deg

ss = State.from_classical(Earth, a, ecc, inc, raan, argp, nu)

from poliastro.plotting import plot
a = 2.5469046 * u.AU
ecc = 0.3119303 * u.one
inc = 8.85664 * u.deg
raan = 64.7265 * u.deg
argp = 310.54879 * u.deg
nu = 111.45799 * u.deg

ss1 = State.from_classical(Earth, a, ecc, inc, raan, argp, nu)



a = 2.7723622 * u.AU
ecc = 0.2310236 * u.one
inc = 34.84095 * u.deg
raan = 173.08828 * u.deg
argp = 309.98943 * u.deg
nu = 163.60442 * u.deg

ss2 = State.from_classical(Earth, a, ecc, inc, raan, argp, nu)


a = 2.2307446 * u.AU
ecc = 0.0835501 * u.one
inc = 5.54664 * u.deg
raan = 85.31897 * u.deg
argp = 6.43834* u.deg
nu = 316.99159 * u.deg

ss3 = State.from_classical(Earth, a, ecc, inc, raan, argp, nu)


from poliastro.plotting import OrbitPlotter
op = OrbitPlotter()
op.plot(ss, label="")
op.plot(ss2, label="")
op.plot(ss1, label="")
op.plot(ss3, label="")
